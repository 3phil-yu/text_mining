# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.datasets import fetch_20newsgroups
from sklearn import datasets
from sklearn.semi_supervised import LabelSpreading
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
categories = [
             'rec.autos',
             'talk.politics.guns',
             'talk.politics.mideast',
             'rec.sport.baseball',
             'comp.sys.mac.hardware',
             'soc.religion.christian']

newsgroup_train = fetch_20newsgroups(subset = 'all',categories = categories)
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)

# %%
rng = np.random.RandomState(0)
indices = np.arange(len(newsgroup_train.target))
rng.shuffle(indices)

# %%
vectorizer = TfidfVectorizer(   stop_words = 'english',
                                max_df = 0.65,
                                ngram_range=(1,2),
                                max_features=15000)

fea_train = vectorizer.fit_transform(newsgroup_train.data)
y_train = newsgroup_train.target

# %%
test_num = 2000

X = fea_train[indices[:test_num ]]
y = y_train[indices[:test_num ]]
images = np.array(newsgroup_train.data)[indices[:test_num]]

n_total_samples = len(y)
n_labeled_points = 300
max_iterations = 20

unlabeled_indices = np.arange(n_total_samples)[n_labeled_points:]

# %%
unlabeled_indices
# Out:
# array([ 300,  301,  302, ..., 1997, 1998, 1999])

# %%
for i in range(max_iterations):
    if len(unlabeled_indices) == 0:
        print("没有待打标的候选标签项")
        break
    y_train = np.copy(y)
    y_train[unlabeled_indices] = -1

    lp_model = LabelSpreading(
                        gamma=0.25, 
                        kernel='knn',
                        alpha = 0.5,
                        n_neighbors =15,
                        max_iter=50,
                        n_jobs = -1
                        )
    lp_model.fit(X.toarray(), y_train)

    predicted_labels = lp_model.transduction_[unlabeled_indices]
    true_labels = y[unlabeled_indices]

    cm = confusion_matrix(true_labels, predicted_labels,
                          labels=lp_model.classes_)

    print("【迭代轮次】 %i %s" % (i, 70 * "_"))
    print("LabelSpreading model: %d 个已标记 & %d 个未标记 (%d 个总数)"
          % (n_labeled_points, n_total_samples - n_labeled_points,
             n_total_samples))

    print(classification_report(
        true_labels, 
            predicted_labels,
            target_names = [
                     'rec.autos',
                     'talk.politics.guns',
                     'talk.politics.mideast',
                     'rec.sport.baseball',
                     'comp.sys.mac.hardware',
                     'soc.religion.christian']
            ))

    print("【混淆矩阵】")
    print(cm)

    # compute the entropies of transduced label distributions
    pred_entropies = stats.distributions.entropy(
        lp_model.label_distributions_.T)

    # select up to 10 digit examples that the classifier is most uncertain about
    uncertainty_index = np.argsort(pred_entropies)[::-1]
    uncertainty_index = uncertainty_index[
        np.in1d(uncertainty_index, unlabeled_indices)][:10]

    # keep track of indices that we get labels for
    delete_indices = np.array([], dtype=int)


    print('【最不确定样本呈现】\n',images)
    for index, image_index in enumerate(uncertainty_index):
        image = images[image_index]


        if i < max_iterations:

            print('……………'*5)
            print("预测标签: {}\n真实标签: {}".format(
                newsgroup_train.target_names[lp_model.transduction_[image_index]], newsgroup_train.target_names[y[image_index]]))
            print('******************'*5)

        # labeling 10 points, remote from labeled set
        delete_index, = np.where(unlabeled_indices == image_index)
        delete_indices = np.concatenate((delete_indices, delete_index))

    unlabeled_indices = np.delete(unlabeled_indices, delete_indices)
    n_labeled_points += len(uncertainty_index)
    print('=========第 {} 轮结束~============'.format(i))
# Out:
# 【迭代轮次】 0 ______________________________________________________________________
# LabelSpreading model: 300 个已标记 & 1700 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.72      0.74      0.73       282
#     talk.politics.guns       0.75      0.77      0.76       281
#  talk.politics.mideast       0.78      0.73      0.75       281
#     rec.sport.baseball       0.87      0.85      0.86       319
#  comp.sys.mac.hardware       0.84      0.81      0.82       268
# soc.religion.christian       0.83      0.91      0.87       269
#
#               accuracy                           0.80      1700
#              macro avg       0.80      0.80      0.80      1700
#           weighted avg       0.80      0.80      0.80      1700
#
# 【混淆矩阵】
# [[209  18  20  13   5  17]
#  [ 30 216  13  10   7   5]
#  [ 17  29 204   8  13  10]
#  [ 11  14   7 270   9   8]
#  [ 14   9  12   8 216   9]
#  [  8   2   7   0   8 244]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# =========第 0 轮结束~============
# 【迭代轮次】 1 ______________________________________________________________________
# LabelSpreading model: 310 个已标记 & 1690 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.74      0.76      0.75       280
#     talk.politics.guns       0.76      0.78      0.77       279
#  talk.politics.mideast       0.77      0.76      0.76       276
#     rec.sport.baseball       0.88      0.84      0.86       318
#  comp.sys.mac.hardware       0.85      0.80      0.82       268
# soc.religion.christian       0.85      0.90      0.87       269
#
#               accuracy                           0.81      1690
#              macro avg       0.81      0.81      0.81      1690
#           weighted avg       0.81      0.81      0.81      1690
#
# 【混淆矩阵】
# [[212  19  16  13   5  15]
#  [ 25 217  16   9   7   5]
#  [ 15  26 209   7  11   8]
#  [ 11  13  11 268   8   7]
#  [ 14  10  13   8 214   9]
#  [  8   2   8   0   8 243]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# =========第 1 轮结束~============
# 【迭代轮次】 2 ______________________________________________________________________
# LabelSpreading model: 320 个已标记 & 1680 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.73      0.79      0.76       275
#     talk.politics.guns       0.75      0.78      0.77       277
#  talk.politics.mideast       0.76      0.76      0.76       274
#     rec.sport.baseball       0.89      0.82      0.86       318
#  comp.sys.mac.hardware       0.85      0.78      0.82       268
# soc.religion.christian       0.84      0.90      0.87       268
#
#               accuracy                           0.81      1680
#              macro avg       0.81      0.81      0.81      1680
#           weighted avg       0.81      0.81      0.81      1680
#
# 【混淆矩阵】
# [[216  17  14   9   4  15]
#  [ 26 216  16   7   7   5]
#  [ 16  25 208   7  10   8]
#  [ 12  17  11 262   8   8]
#  [ 17  10  14   8 210   9]
#  [  8   2   9   0   7 242]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# =========第 2 轮结束~============
# 【迭代轮次】 3 ______________________________________________________________________
# LabelSpreading model: 330 个已标记 & 1670 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.75      0.78      0.76       275
#     talk.politics.guns       0.75      0.81      0.78       274
#  talk.politics.mideast       0.77      0.77      0.77       272
#     rec.sport.baseball       0.91      0.83      0.87       317
#  comp.sys.mac.hardware       0.87      0.80      0.83       265
# soc.religion.christian       0.86      0.91      0.88       267
#
#               accuracy                           0.82      1670
#              macro avg       0.82      0.82      0.82      1670
#           weighted avg       0.82      0.82      0.82      1670
#
# 【混淆矩阵】
# [[214  19  15   9   4  14]
#  [ 22 222  15   6   5   4]
#  [ 15  24 210   6  10   7]
#  [ 12  18   9 264   7   7]
#  [ 14  11  15   5 211   9]
#  [  8   2   8   0   6 243]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# =========第 3 轮结束~============
# 【迭代轮次】 4 ______________________________________________________________________
# LabelSpreading model: 340 个已标记 & 1660 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.75      0.77      0.76       274
#     talk.politics.guns       0.75      0.81      0.78       274
#  talk.politics.mideast       0.77      0.77      0.77       269
#     rec.sport.baseball       0.92      0.83      0.87       317
#  comp.sys.mac.hardware       0.88      0.80      0.84       262
# soc.religion.christian       0.85      0.93      0.89       264
#
#               accuracy                           0.82      1660
#              macro avg       0.82      0.82      0.82      1660
#           weighted avg       0.82      0.82      0.82      1660
#
# 【混淆矩阵】
# [[210  19  17   9   4  15]
#  [ 22 222  15   6   5   4]
#  [ 15  24 208   6  11   5]
#  [ 12  18   9 263   8   7]
#  [ 13  11  14   3 210  11]
#  [  7   1   8   0   2 246]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.guns
# ******************************************************************************************
# =========第 4 轮结束~============
# 【迭代轮次】 5 ______________________________________________________________________
# LabelSpreading model: 350 个已标记 & 1650 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.75      0.78      0.76       272
#     talk.politics.guns       0.75      0.81      0.78       272
#  talk.politics.mideast       0.76      0.77      0.77       267
#     rec.sport.baseball       0.91      0.81      0.86       316
#  comp.sys.mac.hardware       0.87      0.80      0.83       259
# soc.religion.christian       0.86      0.93      0.89       264
#
#               accuracy                           0.82      1650
#              macro avg       0.82      0.82      0.82      1650
#           weighted avg       0.82      0.82      0.82      1650
#
# 【混淆矩阵】
# [[211  17  15   9   5  15]
#  [ 22 219  16   6   6   3]
#  [ 14  25 206   6  11   5]
#  [ 12  19  14 256   8   7]
#  [ 14  11  13   3 208  10]
#  [  7   1   7   1   2 246]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# =========第 5 轮结束~============
# 【迭代轮次】 6 ______________________________________________________________________
# LabelSpreading model: 360 个已标记 & 1640 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.75      0.79      0.77       269
#     talk.politics.guns       0.74      0.82      0.78       268
#  talk.politics.mideast       0.79      0.76      0.78       267
#     rec.sport.baseball       0.93      0.84      0.88       315
#  comp.sys.mac.hardware       0.86      0.80      0.83       258
# soc.religion.christian       0.86      0.92      0.89       263
#
#               accuracy                           0.82      1640
#              macro avg       0.82      0.82      0.82      1640
#           weighted avg       0.83      0.82      0.82      1640
#
# 【混淆矩阵】
# [[212  19  14   6   5  13]
#  [ 21 220  12   5   7   3]
#  [ 16  26 203   6  11   5]
#  [ 10  18   8 264   8   7]
#  [ 14  12  13   3 206  10]
#  [ 11   1   6   1   2 242]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: soc.religion.christian
# ******************************************************************************************
# =========第 6 轮结束~============
# 【迭代轮次】 7 ______________________________________________________________________
# LabelSpreading model: 370 个已标记 & 1630 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.75      0.78      0.77       269
#     talk.politics.guns       0.75      0.82      0.78       268
#  talk.politics.mideast       0.80      0.77      0.78       265
#     rec.sport.baseball       0.91      0.84      0.88       310
#  comp.sys.mac.hardware       0.86      0.81      0.83       256
# soc.religion.christian       0.87      0.92      0.89       262
#
#               accuracy                           0.82      1630
#              macro avg       0.82      0.82      0.82      1630
#           weighted avg       0.83      0.82      0.82      1630
#
# 【混淆矩阵】
# [[209  19  14   9   6  12]
#  [ 21 219  12   6   7   3]
#  [ 15  25 203   6  11   5]
#  [  9  17   8 261   8   7]
#  [ 12  12  12   3 207  10]
#  [ 11   1   5   1   2 242]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: soc.religion.christian
# ******************************************************************************************
# =========第 7 轮结束~============
# 【迭代轮次】 8 ______________________________________________________________________
# LabelSpreading model: 380 个已标记 & 1620 个未标记 (2000 个总数)
# ...
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# =========第 17 轮结束~============
# 【迭代轮次】 18 ______________________________________________________________________
# LabelSpreading model: 480 个已标记 & 1520 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.82      0.81      0.81       246
#     talk.politics.guns       0.74      0.86      0.80       238
#  talk.politics.mideast       0.80      0.80      0.80       243
#     rec.sport.baseball       0.93      0.88      0.91       293
#  comp.sys.mac.hardware       0.90      0.82      0.86       243
# soc.religion.christian       0.90      0.92      0.91       257
#
#               accuracy                           0.85      1520
#              macro avg       0.85      0.85      0.85      1520
#           weighted avg       0.85      0.85      0.85      1520
#
# 【混淆矩阵】
# [[200  17  12   4   4   9]
#  [ 14 204  10   5   3   2]
#  [ 11  22 194   5  10   1]
#  [  5  13   9 258   4   4]
#  [ 10  12  10   3 199   9]
#  [  5   7   6   1   2 236]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: rec.sport.baseball
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: soc.religion.christian
# 真实标签: soc.religion.christian
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.sport.baseball
# 真实标签: soc.religion.christian
# ******************************************************************************************
# =========第 18 轮结束~============
# 【迭代轮次】 19 ______________________________________________________________________
# LabelSpreading model: 490 个已标记 & 1510 个未标记 (2000 个总数)
#                         precision    recall  f1-score   support
#
#              rec.autos       0.82      0.81      0.82       245
#     talk.politics.guns       0.74      0.86      0.80       238
#  talk.politics.mideast       0.80      0.80      0.80       242
#     rec.sport.baseball       0.94      0.89      0.91       290
#  comp.sys.mac.hardware       0.90      0.83      0.86       240
# soc.religion.christian       0.91      0.93      0.92       255
#
#               accuracy                           0.85      1510
#              macro avg       0.85      0.85      0.85      1510
#           weighted avg       0.86      0.85      0.85      1510
#
# 【混淆矩阵】
# [[199  17  14   2   4   9]
#  [ 14 204  10   5   3   2]
#  [ 11  22 194   4  10   1]
#  [  4  13   8 257   4   4]
#  [ 10  12   9   3 199   7]
#  [  5   6   6   1   1 236]]
# 【最不确定样本呈现】
#  ["From: Peter Hansen <pgmoffc@BNR.ca>\nSubject: Re: 72-pin SIMMS, where?\nX-Xxdate: Tue, 20 Apr 93 08:41:49 GMT\nNntp-Posting-Host: bcarm382\nOrganization: BNR\nX-Useragent: Nuntius v1.1.1d17\nLines: 13\n\nIn article <1qulhsINNm22@charnel.ecst.csuchico.edu> Steven Medley,\nsmedley@ecst.csuchico.edu writes:\n>I am looking for a 8 meg 72-pin SIMM for my Centris 610.  Where is the\n>best place to purchase one (stock, shipping, warrenty), and if\n>possible, phone numbers so that I can order one as soon as possible.\n\n  Try Goldstar. They make them, and they are available immediately in Mac\nconfigurations. I ordered a pair from Computerland (8 meg variety) and\nthey work like a charm. I've had them for two weeks.\n\nPeter Hansen\nBell Northern Research\npgmoffc@BNR.ca\n"
#  'From: CROSEN1@ua1vm.ua.edu (Charles Rosen)\nSubject: Lots of runs\nNntp-Posting-Host: ua1vm.ua.edu\nOrganization: The University of Alabama, Tuscaloosa\nLines: 4\n\nI have noticed that this year has had a lot of high scoring games (at least the\nNL has).  I believe one reason are the expansion teams.  Any thoughts?\n \nCharles\n'
#  "From: leapman@austin.ibm.com (Scott Leapman)\nSubject: Re: Half-page hand scanners?\nOriginator: leapman@junior.austin.ibm.com\nReply-To: $LOGIN@austin.ibm.com\nOrganization: IBM Austin\nLines: 8\n\n\nI have a Lightening Scan Pro 256 hand scanner.  It came with scanning/editing\nsoftware, OCR software, and some plug-in modules for Photoshop et al.  The\nscanner was a tad on the pricey side ($480), but the scans are incredibly\naccurate, in 256 level, 300 dpi grayscale.  It also has dithered and line art\nsettings when grayscale isn't desired.  Great scanning software, easy to use.  I\nfrequently write letters to my neices, and spontaneouly include a scanned image\nin the note.  Hope this helps!\n"
#  ...
#  "From: slutsky@tesla.njit.edu\nSubject: Professional Sports on FM Radio\nOrganization: New Jersey Institute of Technology\nLines: 8\nNntp-Posting-Host: tesla\n\nI am curious to known if there are any professional sports teams whose\ngames are regularly broadcast on an FM station.  The only one I am\naware of is WYSP in Philadelphia who carries the Eagles' games.\n\nIf you respond to me I will summarize for the list.\n\nBruce Slutsky\nslutsky@tesla.njit.edu\n"
#  "From: markm@bigfoot.sps.mot.com (Mark Monninger)\nSubject: Re: Borgward question\nNntp-Posting-Host: 223.250.10.7\nReply-To: rapw20@email.sps.mot.com\nOrganization: SPS\nDistribution: usa\nLines: 13\n\nIn article <1r93m7INNnb3@shelley.u.washington.edu>  \nmonet@carson.u.washington.edu (Diana Smith) writes:\n> \n> My ex-husband & I used to own Borgwards. \n> ...\n> even tho' they were\n> ugly - they had names - one was Humphrey Borgward.\n\nThat's pretty good.\n\nA friend had an Audi that he named Murphy.\n\nMark\n"
#  "From: stratton@cwis.unomaha.edu (Dan Stratton)\nSubject: Re: apple's new keybd\nOrganization: University of Nebraska at Omaha\nLines: 10\n\nI use the new keyboard with a IIfx, and I like it. I am not a touch typist\nso some of the advantage is loss on me - but there is difference and less\nstress on my wrists.\n\nDan\n-- \n ---------------------------------------------------\n Dan Stratton              stratton@cwis.unomaha.edu\n Macs, Mercedes, and Money... too much is not enough\n My views are my own.\n"]
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: comp.sys.mac.hardware
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.mideast
# 真实标签: talk.politics.mideast
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: comp.sys.mac.hardware
# 真实标签: rec.autos
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: talk.politics.guns
# 真实标签: talk.politics.guns
# ******************************************************************************************
# …………………………………………………………………
# 预测标签: rec.autos
# 真实标签: talk.politics.guns
# ******************************************************************************************
# =========第 19 轮结束~============
